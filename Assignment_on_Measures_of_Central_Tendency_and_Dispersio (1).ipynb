# %%
import pandas as pd
import statistics as stat

# %%
data=pd.read_csv('/content/StudentsPerformance.csv')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data.mean()
# Out:
# <ipython-input-15-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# math score       66.001
# reading score    69.195
# writing score    68.119
# dtype: float64

# %% [markdown]
# 1. Find out how many males and females participated in the test.

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3      female
# 4      female
#         ...
# 995      male
# 996      male
# 997      male
# 998      male
# 999      male
# Name: gender, Length: 1000, dtype: object

# %% [markdown]
# # 2. What do you think about the students' parental level of education

# %%
 stat.mode(data['parental level of education'])
# Out:
# 'some college'

# %%
data['parental level of education']
# Out:
# 0        some high school
# 1             high school
# 2        some high school
# 3            some college
# 4            some college
#               ...
# 995          some college
# 996          some college
# 997          some college
# 998    associate's degree
# 999     bachelor's degree
# Name: parental level of education, Length: 1000, dtype: object

# %% [markdown]
# # 3. Who scores the most on average for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
import statistics as stat

# %%
data.groupby(['gender','test preparation course']).mean()
# Out:
# <ipython-input-19-02db8c1f5a1b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['gender','test preparation course']).mean()
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 67.108696      77.375000      78.793478
#        none                      61.320359      69.955090      68.982036
# male   completed                 72.988506      70.793103      70.339080
#        none                      66.467532      62.581169      59.551948

# %% [markdown]
# # 4. What do you think about the scoring variation for math, reading and writing
# # based on ● Gender
# # ● Test preparation course

# %%
data.groupby(['gender','test preparation course']).std()
# Out:
# <ipython-input-20-c140453a4120>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['gender','test preparation course']).std()
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 14.428233      12.695493      12.240788
#        none                      16.510686      14.636981      15.016497
# male   completed                 14.039164      13.612420      12.887910
#        none                      14.335746      13.595718      13.468284

# %% [markdown]
# #5 The management needs your help to give bonus points to the top 25% of
# # students based on their math score, so how will you help the management
# ## to achieve this.
# ```

# %%
import numpy as np

# %%
np.percentile(data['math score'],75)
# Out:
# 77.0
